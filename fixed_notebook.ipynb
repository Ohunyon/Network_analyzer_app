# %% [markdown]
# # THREAT DETECTION IN CLOUD SYSTEM
# By

# %% [markdown]
# ### Aims and objectives
# 1. To analyse and design an AI model capable of identifying ransomware attack
# patterns in real-time.
# 2. To explore the effectiveness of different AI techniques (e.g., machine learning, deep
# learning) in enhancing ransomware detection and response.
#
# ### Method we used to achieve this aim and objectives
# 1. Validate the System's Detection and Response Capabilities
# Technical Experiments
# Develop a test environment simulating a cloud-based enterprise network.
# Introduce various ransomware samples and attack vectors into the environment.
# Monitor and document the system's response to each ransomware instance. Here we use our system local environment (mac operating system)
# Outcome
#
# 2. Evaluate System Performance and Effectiveness
# Comparative Analysis:
# Select benchmark tools and existing solutions for comparison (e.g., traditional antivirus software).Conduct
# a series of controlled tests to measure key performance indicators (KPIs) of several machine learning models.
# Use statistical analysis to compare the performance of the developed system against these benchmarks.
#
# 3. Provide Guidance for SMEs
# Guideline Development
# Synthesize findings from experiments and real-world applications to develop practical implementation guidelines.
# Include step-by-step instructions.
# then we created supporting documentation and example configurations.

# %% [markdown]
# ## Creating an AI model capable of identifying ransomware attack patterns in real-time
#
# This is the first objectives we will be working on
#
# Because of several factors that will be listed, we will limit this studies to only identifying ransomware attack patterns using manual input.
# This are the reasons why we will be limiting the studies to manual input rather than realtime input:
# 1. Getting the network packet on our systems needs administrator's priviledges so because of this our system will not allow realtime capturing for security purpose
# 2. Because we are using our local system rather than a cloud the app will not be able to automate because it will be limited to our local system rather than usable on the internet at large

# %% [markdown]
#  ![final architecture AI.png](data:image/png;base64,...)
#
# this section shows the full documentation and of the AI model used to detect the threat in the cloud system. I decided to use machine learning model rather than using Deep learning model as i realise after several researches and iteration that maching learning model is able to do a perfect prediction of the threat as you will see in the notebook
#
# Inorder to get the best model for my research i used `pycaret, pandas, numpy, seaborn, matplotlib, and sklearn `
#
# **PyCaret is an open-source, low-code machine learning library in Python that automates machine learning workflows. It is an end-to-end machine learning and model management tool that speeds up the experiment cycle exponentially and makes you more productive.** [(PyCaret, 2020)](https://pycaret.readthedocs.io/en/latest/index.html)
#
# **Pandas offers data structure and operations for powerful, flexible, and easy-to-use data analysis and manipulation.** [(Pandas, 2008)](https://pandas.pydata.org/docs/getting_started/index.html#getting-started)
#
# **NumPy is a Python library used for working with arrays. It also has functions for working in domain of linear algebra, fourier transform, and matrices.**[(Numpy, 2005)](https://numpy.org/)
#
# **Seaborn is a Python library built on top of the popular visualization library, Matplotlib. It aims to enhance the visual appeal and ease of use of Matplotlib by providing a higher-level interface for creating statistical graphics.**[(Seaborn, 2012)](https://seaborn.pydata.org/whatsnew/v0.12.0.html)
#
# **Matplotlib is a Python library used for creating data visualizations. It is used with Numpy to create publication quality plots.**[(Matplotlib, 2003)](https://matplotlib.org/)
#
# **Sklearn implements numerous data modeling and machine learning algorithms, and provides consistent Python APIs. It supports a standardized and concise model interface across models.**[(Sklearn, 2010)](https://scikit-learn.org/stable/)

# %%
# installing the necessary library to use for our research
# !pip install -Uq pycaret
# !pip install -q shap
# !pip install -q pycaret[analysis]
# !pip install -q pandas
# !pip install -q numpy
# !pip install -q seaborn
# !pip install -q matplotlib
# !pip install -q sklearn
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 1.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 485.7 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 37.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 31.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 63.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 20.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 58.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.1/130.1 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 41.0 MB/s eta 0:00:00
#   Building wheel for pyod (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xgboost 2.1.1 requires nvidia-nccl-cu12; platform_system == "Linux" and platform_machine != "aarch64", which is not installed.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.1/540.1 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 17.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.5/177.5 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.8/287.8 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 40.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 535.7/535.7 kB 29.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.2/356.2 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.5/222.5 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 52.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 70.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.9/778.9 kB 31.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 62.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 15.6 MB/s eta 0:00:00
#   Building wheel for htmlmin (setup.py) ... done
#   Building wheel for dash-cytoscape (setup.py) ... done
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# importing the necessary library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from pycaret.classification import *
from sklearn.preprocessing import OneHotEncoder
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
# Importing the data
# Specify the path to the CSV file
data = pd.read_csv(r"/content/conn4_log_labeled.csv")
data
# Out:
#                    #types                 time       string     addr  \
# 0         1526756261.8665   C9YvmJ3zxtuqxWxLW5  192.168.2.5  38792.0
# 1       1526756268.874876   CGsZqZ3UiQexLzPRVb  192.168.2.5  38792.0
# 2       1526756272.877722   C0LkBW2VEa292Nvet8  192.168.2.5  38793.0
# 3       1526756279.884959   CMDLrn2cVhrqvW8gKa  192.168.2.5  38793.0
# 4       1526756283.888751   C2UM8f4knuL5Vnvp3h  192.168.2.5  38794.0
# ...                   ...                  ...          ...      ...
# 156099  1526886275.954933    Cq9Oi6YyGNTJlf356  192.168.2.5  36647.0
# 156100  1526886282.960912   Cc5Jwn4krKLqvFHdG1  192.168.2.5  36647.0
# 156101  1526886286.965803   Ck8fNL3RpnSPu9Kn9e  192.168.2.5  36648.0
# 156102  1526792995.887377   CY3eGl3hKYsrYxwFv6  192.168.2.5  41501.0
# 156103             #close  2018-05-21-20-53-08          NaN      NaN
#
#                   port   addr.1 port.1 enum      string.1 interval  ...  \
# 0       200.168.87.203  59353.0    tcp    -      2.998333        0  ...
# 1       200.168.87.203  59353.0    tcp    -             -        -  ...
# 2       200.168.87.203  59353.0    tcp    -      2.997182        0  ...
# 3       200.168.87.203  59353.0    tcp    -             -        -  ...
# 4       200.168.87.203  59353.0    tcp    -      2.996286        0  ...
# ...                ...      ...    ...  ...           ...      ...  ...
# 156099  200.168.87.203  59353.0    tcp    -      2.996060        0  ...
# 156100  200.168.87.203  59353.0    tcp    -             -        -  ...
# 156101  200.168.87.203  59353.0    tcp    -      0.995112        0  ...
# 156102     54.39.23.28   2407.0    tcp  irc  93280.030966     6303  ...
# 156103             NaN      NaN    NaN  NaN           NaN      NaN  ...
#
#        bool.1 count.2 string.3   count.3  count.4   count.5  count.6  \
# 0         0.0       S      3.0     180.0      0.0       0.0  (empty)
# 1         0.0       S      1.0      60.0      0.0       0.0  (empty)
# 2         0.0       S      3.0     180.0      0.0       0.0  (empty)
# 3         0.0       S      1.0      60.0      0.0       0.0  (empty)
# 4         0.0       S      3.0     180.0      0.0       0.0  (empty)
# ...       ...     ...      ...       ...      ...       ...      ...
# 156099    0.0       S      3.0     180.0      0.0       0.0  (empty)
# 156100    0.0       S      1.0      60.0      0.0       0.0  (empty)
# 156101    0.0       S      2.0     120.0      0.0       0.0  (empty)
# 156102    0.0  ShADad   3031.0  164117.0   5975.0  289732.0  (empty)
# 156103    NaN     NaN      NaN       NaN      NaN       NaN      NaN
#
#         set[string]                   string.4  string.5
# 0         Malicious  PartOfAHorizontalPortScan       NaN
# 1         Malicious  PartOfAHorizontalPortScan       NaN
# 2         Malicious  PartOfAHorizontalPortScan       NaN
# 3         Malicious  PartOfAHorizontalPortScan       NaN
# 4         Malicious  PartOfAHorizontalPortScan       NaN
# ...             ...                        ...       ...
# 156099    Malicious  PartOfAHorizontalPortScan       NaN
# 156100    Malicious  PartOfAHorizontalPortScan       NaN
# 156101    Malicious  PartOfAHorizontalPortScan       NaN
# 156102    Malicious                        C&C       NaN
# 156103          NaN                        NaN       NaN
#
# [156104 rows x 24 columns]

# %%
# If you want to reset the index of the selected sample
data.reset_index(drop=True, inplace=True)
# Display the selected random sample
data.columns
# Out:
# Index(['#types', 'time', 'string', 'addr', 'port', 'addr.1', 'port.1', 'enum',
#        'string.1', 'interval', 'count', 'count.1', 'string.2', 'bool',
#        'bool.1', 'count.2', 'string.3', 'count.3', 'count.4', 'count.5',
#        'count.6', 'set[string]', 'string.4', 'string.5'],
#       dtype='object')

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS
# I will be checking our data to clean the missing values and futher choosing the feature that will be used for our prediction

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156104 entries, 0 to 156103
# Data columns (total 24 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   #types       156104 non-null  object
#  1   time         156104 non-null  object
#  2   string       156103 non-null  object
#  3   addr         156103 non-null  float64
#  4   port         156103 non-null  object
#  5   addr.1       156103 non-null  float64
#  6   port.1       156103 non-null  object
#  7   enum         156103 non-null  object
#  8   string.1     156103 non-null  object
#  9   interval     156103 non-null  object
#  10  count        156103 non-null  object
#  11  count.1      156103 non-null  object
#  12  string.2     156103 non-null  object
#  13  bool         156103 non-null  object
#  14  bool.1       156103 non-null  float64
#  15  count.2      156103 non-null  object
#  16  string.3     156103 non-null  float64
#  17  count.3      156103 non-null  float64
#  18  count.4      156103 non-null  float64
#  19  count.5      156103 non-null  float64
#  20  count.6      156103 non-null  object
#  21  set[string]  156103 non-null  object
#  22  string.4     156103 non-null  object
#  23  string.5     0 non-null       float64
# dtypes: float64(8), object(16)
# memory usage: 28.6+ MB

# %% [markdown]
# ### cleaning the dataset

# %%
data['set[string]'].value_counts()
# Out:
# set[string]
# Malicious    151567
# Benign         4536
# Name: count, dtype: int64

# %% [markdown]
# From our data we realised that our target variable is 'set[string]' and when we futher check the number of each variable in value count we realized that there are 151567 value of malicious in the dataset and 4536 value of Benign in the dataset, this is very imbalance data sample so we will have to create a balanced data so that our prediction will not be over fitting for the prediction we are trying to acheive. we will be using the value of the Benign for Malicious

# %%
# creating variable for both malicious and benign
malicious = data[data['set[string]'] == 'Malicious']
benign = data[data['set[string]'] == 'Benign']

# %%
# using the sample of the benign to create that of the malicious to give a balanced datase
malicious_sample = malicious.sample(n=len(benign), random_state=42)
malicious_sample.shape
balanced_data = pd.concat([benign, malicious_sample], axis=0)
balanced_data['set[string]'].value_counts()
balanced_data = balanced_data.drop(['string.5'], axis=1)
df = balanced_data

# %% [markdown]
# ### Feature Engineering
#
# On futher investigation on our data we realize that all the dataset can't be used so we will have to used the useful once

# %%
# Choosing the useful columns in the dataset
df_column = ['string', 'port', 'port.1',
       'string.1', 'interval', 'count', 'count.1', 'string.2', 'bool',
       'bool.1', 'string.3', 'count.3', 'set[string]', 'string.4']

data_sub = df[df_column]


categorical_list = []
for col in data_sub.columns:
    if data_sub[col].dtype == 'object':
        categorical_list.append(col)
    else:
      pass
categorical_list
categorical_list.remove('set[string]')
categorical_list
# Out:
# ['string',
#  'port',
#  'port.1',
#  'string.1',
#  'interval',
#  'count',
#  'count.1',
#  'string.2',
#  'bool',
#  'string.4']

# %%
# seperating the numerical type so that the object type can be change to float for perfect prediction using LabelEncoder
selected_data = df[df_column]
numerical_list = selected_data.select_dtypes(include=['float64']).columns
numerical_list
# Out:
# Index(['bool.1', 'string.3', 'count.3'], dtype='object')

# %% [markdown]
# Using LabelEncoder to change the column that are string to floats so that it can be used for prediction as sklearn can't us string for its prediction

# %%
# Initialize the OneHotEncoder
# encoder = OneHotEncoder(sparse_output=False, drop='first')

# Fit and transform the categorical columns
# encoded_features = encoder.fit_transform(df[categorical_list])

# Convert the encoded features to a DataFrame
# encoded_df = pd.DataFrame(encoded_features, columns=encoder.get_feature_names_out(categorical_list))

# Concatenate the encoded columns with the original dataset excluding the original categorical columns
# data_encoded = pd.concat([df[numerical_list], encoded_df, df['set[string]']], axis=1)
# Identify categorical columns

encoders = {}

# Encode each categorical column separately
for col in categorical_list:
  encoder = LabelEncoder()
  encoder.fit(df[col])
  df[col] = encoder.transform(df[col])
  encoders[col] = encoder  # Save encoder for later use (optional)

# Concatenate the encoded features with the original dataset
data_encoded = pd.concat([df[numerical_list], df[categorical_list], df['set[string]']], axis=1)
data_encoded.head()
# Out:
#     bool.1  string.3  count.3  string  port  port.1  string.1  interval  \
# 13     0.0       1.0     76.0     359  6029       2       288        27
# 14     0.0       6.0    456.0     359  5527       2      5413        16
# 15     0.0       6.0    456.0     359  5193       2      5420        16
# 22     0.0       7.0    532.0     359  5528       2      5666        22
# 29     0.0       1.0     76.0     359  5193       2       522        27
#
#     count  count.1  string.2  bool  string.4 set[string]
# 13     63        8         0     0         0      Benign
# 14     58        8         0     0         0      Benign
# 15     58        8         0     0         0      Benign
# 22     61        8         0     0         0      Benign
# 29     63        8         0     0         0      Benign

# %%
data_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9072 entries, 13 to 70124
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   bool.1       9072 non-null   float64
#  1   string.3     9072 non-null   float64
#  2   count.3      9072 non-null   float64
#  3   string       9072 non-null   int64
#  4   port         9072 non-null   int64
#  5   port.1       9072 non-null   int64
#  6   string.1     9072 non-null   int64
#  7   interval     9072 non-null   int64
#  8   count        9072 non-null   int64
#  9   count.1      9072 non-null   int64
#  10  string.2     9072 non-null   int64
#  11  bool         9072 non-null   int64
#  12  string.4     9072 non-null   int64
#  13  set[string]  9072 non-null   object
# dtypes: float64(3), int64(10), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# ## DATA PREDICTION
# For this section we will be predicting using pycaret that has over 18 model and we will be comparing all the model then choose the best 2 model and visualize it so that we will get a full picture of how the prediction is going
#
# ### This next code will Conduct a series of controlled tests to measure key performance indicators (KPIs) of several machine learning models. Use statistical analysis to compare the performance of the developed system against these benchmarks.

# %%
# Remove rows with missing values in the target column
data_encoded = data_encoded.dropna(subset=['set[string]'])
# Initialize PyCaret with the encoded dataset
clf_setup = setup(data=data_encoded, target='set[string]')

# Compare models and get the top 2 models
top_models = compare_models(n_select=2)

# Select the best model
best_model = top_models[0]

# Train the best model on the entire dataset
final_model = finalize_model(best_model)

# Make predictions
predictions = predict_model(final_model)


# Select the next best model (second-best model)
next_best_model = top_models[1]

# Finalize the next best model
final_next_best_model = finalize_model(next_best_model)

# Make predictions
predictions_next = predict_model(final_next_best_model)
# Out:
# <style type="text/css">
# #T_cb9ed_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cb9ed" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb9ed_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cb9ed_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb9ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb9ed_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_cb9ed_row0_col1" class="data row0 col1" >7616</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb9ed_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cb9ed_row1_col1" class="data row1 col1" >set[string]</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cb9ed_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_cb9ed_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cb9ed_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_cb9ed_row3_col1" class="data row3 col1" >Benign: 0, Malicious: 1</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cb9ed_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_cb9ed_row4_col1" class="data row4 col1" >(9072, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cb9ed_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_cb9ed_row5_col1" class="data row5 col1" >(9072, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cb9ed_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_cb9ed_row6_col1" class="data row6 col1" >(6350, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cb9ed_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_cb9ed_row7_col1" class="data row7 col1" >(2722, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cb9ed_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_cb9ed_row8_col1" class="data row8 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cb9ed_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_cb9ed_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cb9ed_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_cb9ed_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cb9ed_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_cb9ed_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cb9ed_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_cb9ed_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cb9ed_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_cb9ed_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cb9ed_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_cb9ed_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cb9ed_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_cb9ed_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cb9ed_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_cb9ed_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_cb9ed_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_cb9ed_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_cb9ed_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_cb9ed_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_cb9ed_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_cb9ed_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_cb9ed_row19_col1" class="data row19 col1" >6ab0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_907bb th {
#   text-align: left;
# }
# #T_907bb_row0_col0, #T_907bb_row1_col0, #T_907bb_row2_col0, #T_907bb_row3_col0, #T_907bb_row4_col0, #T_907bb_row5_col0, #T_907bb_row6_col0, #T_907bb_row7_col0, #T_907bb_row8_col0, #T_907bb_row8_col1, #T_907bb_row8_col3, #T_907bb_row8_col4, #T_907bb_row8_col5, #T_907bb_row8_col6, #T_907bb_row8_col7, #T_907bb_row9_col0, #T_907bb_row9_col1, #T_907bb_row9_col2, #T_907bb_row9_col3, #T_907bb_row9_col4, #T_907bb_row9_col5, #T_907bb_row9_col6, #T_907bb_row9_col7, #T_907bb_row10_col0, #T_907bb_row10_col1, #T_907bb_row10_col2, #T_907bb_row10_col3, #T_907bb_row10_col4, #T_907bb_row10_col5, #T_907bb_row10_col6, #T_907bb_row10_col7, #T_907bb_row11_col0, #T_907bb_row11_col1, #T_907bb_row11_col2, #T_907bb_row11_col3, #T_907bb_row11_col4, #T_907bb_row11_col5, #T_907bb_row11_col6, #T_907bb_row11_col7, #T_907bb_row12_col0, #T_907bb_row12_col1, #T_907bb_row12_col2, #T_907bb_row12_col3, #T_907bb_row12_col4, #T_907bb_row12_col5, #T_907bb_row12_col6, #T_907bb_row12_col7, #T_907bb_row13_col0, #T_907bb_row13_col1, #T_907bb_row13_col2, #T_907bb_row13_col3, #T_907bb_row13_col4, #T_907bb_row13_col5, #T_907bb_row13_col6, #T_907bb_row13_col7, #T_907bb_row14_col0, #T_907bb_row14_col1, #T_907bb_row14_col2, #T_907bb_row14_col3, #T_907bb_row14_col4, #T_907bb_row14_col5, #T_907bb_row14_col6, #T_907bb_row14_col7 {
#   text-align: left;
# }
# #T_907bb_row0_col1, #T_907bb_row0_col2, #T_907bb_row0_col3, #T_907bb_row0_col4, #T_907bb_row0_col5, #T_907bb_row0_col6, #T_907bb_row0_col7, #T_907bb_row1_col1, #T_907bb_row1_col2, #T_907bb_row1_col3, #T_907bb_row1_col4, #T_907bb_row1_col5, #T_907bb_row1_col6, #T_907bb_row1_col7, #T_907bb_row2_col1, #T_907bb_row2_col2, #T_907bb_row2_col3, #T_907bb_row2_col4, #T_907bb_row2_col5, #T_907bb_row2_col6, #T_907bb_row2_col7, #T_907bb_row3_col1, #T_907bb_row3_col2, #T_907bb_row3_col3, #T_907bb_row3_col4, #T_907bb_row3_col5, #T_907bb_row3_col6, #T_907bb_row3_col7, #T_907bb_row4_col1, #T_907bb_row4_col2, #T_907bb_row4_col3, #T_907bb_row4_col4, #T_907bb_row4_col5, #T_907bb_row4_col6, #T_907bb_row4_col7, #T_907bb_row5_col1, #T_907bb_row5_col2, #T_907bb_row5_col3, #T_907bb_row5_col4, #T_907bb_row5_col5, #T_907bb_row5_col6, #T_907bb_row5_col7, #T_907bb_row6_col1, #T_907bb_row6_col2, #T_907bb_row6_col3, #T_907bb_row6_col4, #T_907bb_row6_col5, #T_907bb_row6_col6, #T_907bb_row6_col7, #T_907bb_row7_col1, #T_907bb_row7_col2, #T_907bb_row7_col3, #T_907bb_row7_col4, #T_907bb_row7_col5, #T_907bb_row7_col6, #T_907bb_row7_col7, #T_907bb_row8_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_907bb_row0_col8, #T_907bb_row1_col8, #T_907bb_row2_col8, #T_907bb_row3_col8, #T_907bb_row4_col8, #T_907bb_row5_col8, #T_907bb_row6_col8, #T_907bb_row7_col8, #T_907bb_row8_col8, #T_907bb_row9_col8, #T_907bb_row10_col8, #T_907bb_row11_col8, #T_907bb_row12_col8, #T_907bb_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_907bb_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_907bb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_907bb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_907bb_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_907bb_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_907bb_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_907bb_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_907bb_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_907bb_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_907bb_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_907bb_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_907bb_level0_row0" class="row_heading level0 row0" >nb</th>
#       <td id="T_907bb_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_907bb_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_907bb_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_907bb_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_907bb_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_907bb_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_907bb_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_907bb_row0_col7" class="data row0 col7" >1.0000</td>
#       <td id="T_907bb_row0_col8" class="data row0 col8" >0.0640</td>
#     </tr>
#     <tr>
#       <th id="T_907bb_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_907bb_row1_col0" class="data row1 col0" >Decision Tree Classifier</td>
#       <td id="T_907bb_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_907bb_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_907bb_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_907bb_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_907bb_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_907bb_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_907bb_row1_col7" class="data row1 col7" >1.0000</td>
#       <td id="T_907bb_row1_col8" class="data row1 col8" >0.0660</td>
#     </tr>
#     <tr>
#       <th id="T_907bb_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_907bb_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_907bb_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_907bb_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_907bb_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_907bb_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_907bb_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_907bb_row2_col6" class="data row2 col6" >1.0000</td>
#       <td id="T_907bb_row2_col7" class="data row2 col7" >1.0000</td>
#       <td id="T_907bb_row2_col8" class="data row2 col8" >0.4640</td>
#     </tr>
#     <tr>
#       <th id="T_907bb_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_907bb_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_907bb_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_907bb_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_907bb_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_907bb_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_907bb_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_907bb_row3_col6" class="data row3 col6" >1.0000</td>
#       <td id="T_907bb_row3_col7" class="data row3 col7" >1.0000</td>
#       <td id="T_907bb_row3_col8" class="data row3 col8" >0.1100</td>
#     </tr>
#     <tr>
#       <th id="T_907bb_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_907bb_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_907bb_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_907bb_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_907bb_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_907bb_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_907bb_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_907bb_row4_col6" class="data row4 col6" >1.0000</td>
#       <td id="T_907bb_row4_col7" class="data row4 col7" >1.0000</td>
#       <td id="T_907bb_row4_col8" class="data row4 col8" >0.3610</td>
#     </tr>
#     <tr>
#       <th id="T_907bb_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_907bb_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_907bb_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_907bb_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_907bb_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_907bb_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_907bb_row5_
# Processing:   0%|          | 0/66 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_9f25e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f25e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9f25e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_9f25e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_9f25e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9f25e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_9f25e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_9f25e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_9f25e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f25e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9f25e_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_9f25e_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_9f25e_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_9f25e_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_9f25e_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_9f25e_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_9f25e_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_9f25e_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_3086d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3086d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3086d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3086d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3086d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3086d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3086d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3086d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3086d_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3086d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3086d_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_3086d_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_3086d_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_3086d_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_3086d_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_3086d_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_3086d_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_3086d_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# for this code we can see that some model predicted a perfect result like Naive Bayes,
# Decision Tree Classifier, Random Forest Classifier, Ada Boost Classifier, Gradient Boosting Classifier, Extra Trees Classifier, Extreme Gradient Boosting, Light Gradient Boosting Machine. this model got 100% accuracy for the prediction, so we will be using the best two of this which is the *Naive Bayes Classifier and Decision Tree Classifier* as it came top on the list

# %%
# prompt: for values in data_encoded['set[string]'] i want Malicious to be 1 and benign to be 0 then they should be stored in another column called target

data_encoded['target'] = data_encoded['set[string]'].apply(lambda x: 1 if x == 'Malicious' else 0)
data_encoded.drop('set[string]', axis=1, inplace=True)
data_encoded.head()
# Out:
#     bool.1  string.3  count.3  string  port  port.1  string.1  interval  \
# 13     0.0       1.0     76.0     359  6029       2       288        27
# 14     0.0       6.0    456.0     359  5527       2      5413        16
# 15     0.0       6.0    456.0     359  5193       2      5420        16
# 22     0.0       7.0    532.0     359  5528       2      5666        22
# 29     0.0       1.0     76.0     359  5193       2       522        27
#
#     count  count.1  string.2  bool  string.4  target
# 13     63        8         0     0         0       0
# 14     58        8         0     0         0       0
# 15     58        8         0     0         0       0
# 22     61        8         0     0         0       0
# 29     63        8         0     0         0       0

# %% [markdown]
# ## Evaluation of the two model

# %%
# help(plot_model)

# %%
# Import the plot_model function
from pycaret.classification import plot_model

# Visualize the model
print('Navies Bayes')
plot_model(final_model, plot='boundary')
print('Decision Tree Classifier')
plot_model(final_next_best_model, plot='boundary')
# Out:
# Navies Bayes
# Decision Tree Classifier

# %% [markdown]
# From this model we see that Navies Bayes Classifier only capture one side of the dataset and did not capture the second area of the attack in the dataset, but the Decision tree classifier captures both sides.  so eventhough both of the model predicted 100% the diagram shows that when more data are inputted it is likely for the Navies bayes not to capture the Malicious from the network well.
#
# so we will be using the Decision Tree Classifer for our prediction

# %%
# Correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(data_encoded.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# The correlation matrix shows the relationship of the columns in the dataset, as we see our major target is the "Target" variable and we see how each features worked with it

# %% [markdown]
# ## SAVING OUR MODEL FOR DEPLOYMENT

# %%
# Save (pickle) the best model
save_model(final_model, 'next_best_model')

# (Optional) Load the saved model
loaded_model = load_model('next_best_model')

# Make predictions
predictions = predict_model(loaded_model)

# Display the predicted results
print("Predicted Results:")
predictions.head()
# Out:
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Loaded
# <style type="text/css">
# </style>
# <table id="T_8fe75" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8fe75_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8fe75_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8fe75_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8fe75_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8fe75_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8fe75_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8fe75_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8fe75_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8fe75_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8fe75_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_8fe75_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_8fe75_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_8fe75_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_8fe75_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_8fe75_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_8fe75_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_8fe75_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#   </tbody>
# </table>
# Predicted Results:
#         bool.1  string.3  count.3  string  port  port.1  string.1  interval  \
# 120079     0.0       1.0     60.0     359  5580       1         0         0
# 21046      0.0       1.0     60.0     359  4159       1         0         0
# 80702      0.0       1.0     60.0     359  3707       1      2380         1
# 54841      0.0       3.0    180.0     359  1652       1      3354         1
# 9762       0.0       1.0     60.0     359  5995       1         0         0
#
#         count  count.1  string.2  bool  string.4 set[string] prediction_label  \
# 120079      0        5         0     0         2   Malicious        Malicious
# 21046       0        5         0     0         2   Malicious        Malicious
# 80702       1        1         0     0         0      Benign           Benign
# 54841       1        5         0     0         2   Malicious        Malicious
# 9762        0        5         0     0         2   Malicious        Malicious
#
#         prediction_score
# 120079               1.0
# 21046                1.0
# 80702                1.0
# 54841                1.0
# 9762                 1.0

# %% [markdown]
# Now that we are done with the AI model and we have compared several models to get the best for our prediction the next thing is to put this out for end users

# %% [markdown]
# ## Creating the system that will sniff the packet on our system environment and the app that will do the prediction and stop the attack

# %% [markdown]
# ## REFERENCES
#
# McKinney, W. (2010). Data Structures for Statistical Computing in Python. In Proceedings of the 9th Python in Science Conference, 51-56. Retrieved from https://pandas.pydata.org/docs/
#
# Harris, C. R., Millman, K. J., van der Walt, S. J., Gommers, R., Virtanen, P., Cournapeau, D., ... & Oliphant, T. E. (2020). Array programming with NumPy. Nature, 585(7825), 357-362. Retrieved from https://numpy.org/doc/
#
# Waskom, M. (2021). seaborn: statistical data visualization. Journal of Open Source Software, 6(60), 3021. Retrieved from https://seaborn.pydata.org/
#
# Hunter, J. D. (2007). Matplotlib: A 2D graphics environment. Computing in Science & Engineering, 9(3), 90-95. Retrieved from https://matplotlib.org/stable/contents.html
#
# Pedregosa, F., Varoquaux, G., Gramfort, A., Michel, V., Thirion, B., Grisel, O., ... & Duchesnay, É. (2011). Scikit-learn: Machine learning in Python. Journal of Machine Learning Research, 12, 2825-2830. Retrieved from https://scikit-learn.org/stable/documentation.html
#
# Ali, M., Jabeen, F., & ur Rehman, S. (2020). PyCaret: An open source, low-code machine learning library in Python. Retrieved from https://pycaret.readthedocs.io/en/latest/

# %%
print("""
░██████╗███████╗░█████╗░██████╗░███████╗
██╔════╝██╔════╝██╔══██╗██╔══██╗██╔════╝
╚█████╗░█████╗░░██║░░██║██████╔╝█████╗░░
░╚═══██╗██╔══╝░░██║░░██║██╔══██╗██╔══╝░░
██████╔╝███████╗╚█████╔╝██║░░██║███████╗
╚═════╝░╚══════╝░╚════╝░╚═╝░░╚═╝╚══════╝
""")
# Out:
# ░██████╗███████╗░█████╗░██████╗░███████╗
# ██╔════╝██╔════╝██╔══██╗██╔══██╗██╔════╝
# ╚█████╗░█████╗░░██║░░██║██████╔╝█████╗░░
# ░╚═══██╗██╔══╝░░██║░░██║██╔══██╗██╔══╝░░
# ██████╔╝███████╗╚█████╔╝██║░░██║███████╗
# ╚═════╝░╚══════╝░╚════╝░╚═╝░░╚═╝╚══════╝
